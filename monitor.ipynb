# %%
import os
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
in_dir = 'checkpoints/Outdoor_nyu_wsupervised/web/images'

# %%
os.listdir(in_dir)
# Out:
# ['epoch001_lab_t.png',
#  'epoch001_img_t.png',
#  'epoch001_lab_t_g.png',
#  'epoch001_img_t2t.png',
#  'epoch001_img_s2t.png',
#  'epoch001_lab_s.png',
#  'epoch001_img_s.png',
#  'epoch001_lab_s_g.png']

# %%
for f in os.listdir(in_dir):
    print(f)
    f_path = os.path.join(in_dir, f)
    arr = cv2.imread(f_path)
    plt.imshow(arr)
    plt.show()
# Out:
# epoch001_lab_t.png
# epoch001_img_t.png
# epoch001_lab_t_g.png
# epoch001_img_t2t.png
# epoch001_img_s2t.png
# epoch001_lab_s.png
# epoch001_img_s.png
# epoch001_lab_s_g.png
